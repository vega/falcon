# %%
import pyarrow as pa
import dataio
import pandas as pd

# %%
df = pd.read_json('movies.json', encoding='utf-8')

# %%
# convert Title to string dtype
df["Title"] = df["Title"].astype(str)
df
# Out:
#                            Title    US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 0                 The Land Girls    146083.0         146083.0           NaN
# 1         First Love, Last Rites     10876.0          10876.0           NaN
# 2     I Married a Strange Person    203134.0         203134.0           NaN
# 3           Let's Talk About Sex    373615.0         373615.0           NaN
# 4                           Slam   1009819.0        1087521.0           NaN
# ...                          ...         ...              ...           ...
# 3196  Zack and Miri Make a Porno  31452765.0       36851125.0    21240321.0
# 3197                      Zodiac  33080084.0       83080084.0    20983030.0
# 3198                        Zoom  11989328.0       12506188.0     6679409.0
# 3199         The Legend of Zorro  45575336.0      141475336.0           NaN
# 3200           The Mask of Zorro  93828745.0      233700000.0           NaN
#
# ...

# %%
table = pa.Table.from_pandas(df)

# %%
dataio.table_to_arrow_file(table, 'exp1.arrow')
dataio.table_to_parquet_file(table, 'exp1.parquet')

# %%
def filter_between(table, column_name, a, b):
    return table[(table[column_name] >= a) & (table[column_name] <= b)]

# %%
filter_between(df, "IMDB_Rating", 6.41, 8.52)
# Out:
#                            Title    US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 1         First Love, Last Rites     10876.0          10876.0           NaN
# 2     I Married a Strange Person    203134.0         203134.0           NaN
# 6                      Following     44705.0          44705.0           NaN
# 9                Duel in the Sun  20400000.0       20400000.0           NaN
# 10                     Tom Jones  37600000.0       37600000.0           NaN
# ...                          ...         ...              ...           ...
# 3191          The Young Victoria  11001272.0       11001272.0     3273039.0
# 3193                 Zero Effect   2080693.0        2080693.0           NaN
# 3195                  Zombieland  75590286.0       98690286.0    28281155.0
# 3196  Zack and Miri Make a Porno  31452765.0       36851125.0    21240321.0
# 3200           The Mask of Zorro  93828745.0      233700000.0           NaN
#
# ...
