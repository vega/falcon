# %%
import pandas as pd
import pyarrow as pa

# %%
df = pd.read_json('./movies.json')
df = df[df.columns[1:]]

# %%
df
# Out:
#         US_Gross  Worldwide_Gross  US_DVD_Sales  Production_Budget  \
# 0       146083.0         146083.0           NaN          8000000.0
# 1        10876.0          10876.0           NaN           300000.0
# 2       203134.0         203134.0           NaN           250000.0
# 3       373615.0         373615.0           NaN           300000.0
# 4      1009819.0        1087521.0           NaN          1000000.0
# ...          ...              ...           ...                ...
# 3196  31452765.0       36851125.0    21240321.0         24000000.0
# 3197  33080084.0       83080084.0    20983030.0         85000000.0
# 3198  11989328.0       12506188.0     6679409.0         35000000.0
# 3199  45575336.0      141475336.0           NaN         80000000.0
# 3200  93828745.0      233700000.0           NaN         65000000.0
#
#      Release_Date MPAA_Rating  Running_Time_min         Distributor  \
# 0       12-Jun-98           R               NaN            Gramercy
# 1        7-Aug-98           R               NaN              Strand
# 2       28-Aug-98        None               NaN           Lionsgate
# 3       11-Sep-98        None               NaN           Fine Line
# 4        9-Oct-98           R               NaN             Trimark
# ...           ...         ...               ...                 ...
# 3196    31-Oct-08           R             101.0       Weinstein Co.
# 3197     2-Mar-07           R             157.0  Paramount Pictures
# 3198    11-Aug-06          PG               NaN       Sony Pictures
# 3199    28-Oct-05          PG             129.0       Sony Pictures
# 3200    17-Jul-98       PG-13             136.0       Sony Pictures
#
#                             Source        Major_Genre         Creative_Type  \
# 0                             None               None                  None
# 1                             None              Drama                  None
# 2                             None             Comedy                  None
# 3                             None             Comedy                  None
# 4              Original Screenplay              Drama  Contemporary Fiction
# ...                            ...                ...                   ...
# 3196           Original Screenplay             Comedy  Contemporary Fiction
# 3197     Based on Book/Short Story  Thriller/Suspense         Dramatization
# 3198  Based on Comic/Graphic Novel          Adventure            Super Hero
# 3199                        Remake          Adventure    Historical Fiction
# 3200                        Remake          Adventure    Historical Fiction
#
#              Director  Rotten_Tomatoes_Rating  IMDB_Rating  IMDB_Votes
# 0                None                     NaN          6.1      1071.0
# 1                None                     NaN          6.9       207.0
# 2                None                     NaN          6.8       865.0
# 3                None                    13.0          NaN         NaN
# 4                None                    62.0          3.4       165.0
# ...               ...                     ...          ...         ...
# 3196      Kevin Smith                    65.0          7.0     55687.0
# 3197    David Fincher                    89.0          NaN         NaN
# 3198     Peter Hewitt                     3.0          3.4      7424.0
# 3199  Martin Campbell                    26.0          5.7     21161.0
# 3200  Martin Campbell                    82.0          6.7      4789.0
#
# [3201 rows x 15 columns]

# %%
def pandas_to_arrow_file(df, filename="default.arrow"):
	table = pa.Table.from_pandas(df)
	writer = pa.RecordBatchFileWriter(filename, table.schema)
	writer.write(table)
	writer.close()

# %%
pandas_to_arrow_file(df, "movies-3k.arrow")
