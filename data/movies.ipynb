# %%
import pandas as pd
import pyarrow as pa
import dataio as io

# %%
df = pd.read_json('./movies-3k.json')
df.drop("Title", axis=1, inplace=True)

# %%
df.head()
# Out:
#     US_Gross  Worldwide_Gross  US_DVD_Sales  Production_Budget Release_Date  \
# 0   146083.0         146083.0           NaN          8000000.0  Jun 12 1998
# 1    10876.0          10876.0           NaN           300000.0  Aug 07 1998
# 2   203134.0         203134.0           NaN           250000.0  Aug 28 1998
# 3   373615.0         373615.0           NaN           300000.0  Sep 11 1998
# 4  1009819.0        1087521.0           NaN          1000000.0  Oct 09 1998
#
#   MPAA_Rating  Running_Time_min Distributor               Source Major_Genre  \
# 0           R               NaN    Gramercy                 None        None
# 1           R               NaN      Strand                 None       Drama
# 2        None               NaN   Lionsgate                 None      Comedy
# 3        None               NaN   Fine Line                 None      Comedy
# 4           R               NaN     Trimark  Original Screenplay       Drama
#
#           Creative_Type Director  Rotten_Tomatoes_Rating  IMDB_Rating  \
# 0                  None     None                     NaN          6.1
# 1                  None     None                     NaN          6.9
# 2                  None     None                     NaN          6.8
# 3                  None     None                    13.0          NaN
# 4  Contemporary Fiction     None                    62.0          3.4
#
#    IMDB_Votes
# 0      1071.0
# 1       207.0
# 2       865.0
# 3         NaN
# 4       165.0

# %%
# encode the data column correctly
df["Release_Date"] = pd.to_datetime(df["Release_Date"])

# %%
df.head()
# Out:
#     US_Gross  Worldwide_Gross  US_DVD_Sales  Production_Budget Release_Date  \
# 0   146083.0         146083.0           NaN          8000000.0   1998-06-12
# 1    10876.0          10876.0           NaN           300000.0   1998-08-07
# 2   203134.0         203134.0           NaN           250000.0   1998-08-28
# 3   373615.0         373615.0           NaN           300000.0   1998-09-11
# 4  1009819.0        1087521.0           NaN          1000000.0   1998-10-09
#
#   MPAA_Rating  Running_Time_min Distributor               Source Major_Genre  \
# 0           R               NaN    Gramercy                 None        None
# 1           R               NaN      Strand                 None       Drama
# 2        None               NaN   Lionsgate                 None      Comedy
# 3        None               NaN   Fine Line                 None      Comedy
# 4           R               NaN     Trimark  Original Screenplay       Drama
#
#           Creative_Type Director  Rotten_Tomatoes_Rating  IMDB_Rating  \
# 0                  None     None                     NaN          6.1
# 1                  None     None                     NaN          6.9
# 2                  None     None                     NaN          6.8
# 3                  None     None                    13.0          NaN
# 4  Contemporary Fiction     None                    62.0          3.4
#
#    IMDB_Votes
# 0      1071.0
# 1       207.0
# 2       865.0
# 3         NaN
# 4       165.0

# %%
table = pa.Table.from_pandas(df)

# %%
io.table_to_arrow_file(table, "movies-3k.arrow")
io.table_to_parquet_file(table, "movies-3k.parquet")
